# %%
# https://github.com/mazurowski-lab/duke-dbt-data
import os

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from duke_dbt_data import dcmread_image

# %%
df = pd.read_csv("data/file-paths-validation.csv")

# %%
view_series = df.iloc[0]
view = view_series["View"]
# if you have image data saved in classic path folder structure, read the file path from "classic_path"
# image_path = os.path.join("/data", view_series["classic_path"])

image_path = os.path.join("G:/Radiografias Validacion", view_series["descriptive_path"])

# Reemplazar "NA" con otro valor
image_path = image_path.replace("000000-", "000000-NA-")

print("Ruta original:", image_path)
#print("Ruta modificada:", new_image_path)
# Out:
# Ruta original: G:/Radiografias Validacion\Breast-Cancer-Screening-DBT/DBT-P00002/01-01-2000-DBT-S03345-MAMMO diagnostic digital bilateral-69013/21098.000000-NA-91129/1-1.dcm

# %%
# %%time
image = dcmread_image(fp=image_path, view=view)
# Out:
# Exception in thread Thread-5 (load_dicom):
# Traceback (most recent call last):
#   File "C:\Users\Miguel\anaconda3\envs\tf\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Miguel\anaconda3\envs\tf\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "D:\Codigo\Procesamiento_Gradiografias\Ejemplos\duke_dbt_data.py", line 15, in load_dicom
#     ds = dicom.dcmread(fp)
#   File "C:\Users\Miguel\anaconda3\envs\tf\lib\site-packages\pydicom\filereader.py", line 1002, in dcmread
#     fp = open(fp, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\Breast-Cancer-Screening-DBT/DBT-P00002/01-01-2000-DBT-S03345-MAMMO diagnostic digital bilateral-69013/21098.000000-NA-91129/1-1.dcm'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# File D:\Codigo\Procesamiento_Gradiografias\Ejemplos\duke_dbt_data.py:25, in dcmread_image(fp, view, index)
#      22 thread.join()
#      24 # Una vez cargado el archivo DICOM, procesarlo
# ---> 25 ds.decompress(handler_name="pillow")
#      26 pixel_array = ds.pixel_array
#      27 view_laterality = view[0].upper()
#
# NameError: name 'ds' is not defined

# %%
plt.imshow(image[0], cmap=plt.cm.gray);
